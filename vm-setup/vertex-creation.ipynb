# %% [markdown]
# Name
# drg-data-pipeline
# Must start with a letter followed by up to 47 lowercase letters, numbers, or hyphens (-) and cannot end with a hyphen
# Region
# us-central1 (Iowa)
# Zone
# us-central1-a
#
# Enable Dataproc Serverless Interactive Sessions
# Enable access to Dataproc Spark kernels
#
# Labels
# Network tags
# Network tags
# Assign tags to your Workbench resource Learn more
# Workbench type
# Instead of creating a Vertex AI Workbench instance, you can create a user-managed or managed notebook using the same configuration. These are older versions of Workbench and not recommended unless you have a specific need.
# Type
# Instance

# %% [markdown]
# Environment
# All environments use JupyterLab 3 by default and have the latest NVIDIA GPU and Intel libraries and drivers installed. You can specify a previous version instead. Learn more
#
# Use custom container:
# gcr.io/deeplearning-platform-release/r-cpu.4-4:latest
#
# Version
# Use the latest version
# Use a previous version
# To learn more about specific versions, see the Vertex AI Workbench release notes.
# Post-startup script
# Path to post-startup script
# Cloud Storage path to script that automatically runs after the instance boots up
#
# Metadata
# Some metadata keys including data-disk-uri, enable-oslogin, framework, notebooks-api, notebooks-api-version, nvidia-driver-gcs-path, proxy-url, restriction, shutdown-script, title, version are reserved for system use only. If you use these variable names below, they will be overwritten by system values.

# %% [markdown]
# Machine type
#
#
#
# Machine types for common workloads, optimized for cost and flexibility
# Series
# Description
# vCPUs
# Memory
# Platform
#
# E2	Low cost, day-to-day computing	2 - 32	4 - 128 GB	Based on availability
#
# N2	Balanced price & performance	2 - 128	4 - 864 GB	Intel Cascade and Ice Lake
#
# N2D	Balanced price & performance	2 - 224	4 - 896 GB	AMD EPYC
#
# N1	Balanced price & performance	2 - 32	7.5 - 208 GB	Intel Skylake
# Machine type
# e2-highmem-4 (4 vCPU, 2 core, 32 GB memory)
# vCPU 4 Memory 32 GB
#
# GPUs
# The number of attached GPUs affects the VM's maximum number of memory and CPUs. Learn More
#
# Shielded VM
# Turn on all settings for the most secure configuration. Learn more
#
# Secure Boot
# Verifies the digital signature of all boot components to protect against boot-level and kernel-level malware. Not supported for instances with GPUs.
#
# Virtual Trusted Platform Module (vTPM)
# Validates guest VM pre-boot and boot integrity, and offers key generation and protection.
#
# Integrity monitoring
# Monitors and verifies runtime boot integrity using Stackdriver. Requires vTPM.
# Idle shutdown
#
# Enable Idle Shutdown
# Time of inactivity before shutdown (Minutes)
# 10
# Range: 10 minutes to 1 day (1,440 minutes)

# %% [markdown]
# Disks
# Boot disk type
# SSD Persistent Disk
# Boot disk size in GB
# 150
# Data disk type
# SSD Persistent Disk
# Data disk size in GB
# 100
#
# Delete to trash
# Deleting in JupyterLab will use the operating system's trash behavior
# Encryption
#
# Google-managed encryption key
# Keys owned by Google
#
# Cloud KMS key
# Keys owned by customers

# %% [markdown]
# Networking
# The instance requires internet access to be used. Make sure one of the following is selected. Learn more
# Assign an external IP address
# Select a network that has internet access
# Turn on Private Google Access
#
# Network in this project
#
# Shared network
# Network
# default
# Subnetwork
# default(10.128.0.0/20)
#
# Assign external IP address
# Lets the instance communicate with the internet or other VPC networks
#
# Allow proxy access
# If proxy access is disabled, you must SSH to access your instance. Learn more

# %% [markdown]
# IAM and security
# Determines who can use the instance's JupyterLab interface. This cannot be changed after the instance is created. Learn more
#
# Service account
# Anyone with the iam.serviceAccounts.actAs can access the instance account
#
# Single user
# Restricts access to one user
#
# Use default Compute Engine service account
# If you've made changes to the default Compute Engine service account, check that it still has sufficient API permissions. Learn more
# Security options
#
# Root access to the instance
#
# nbconvert
# Export and download notebooks as a different file type
#
# File downloading
# Allow downloads from JupyterLab
#
# Terminal access
# Run shell commands from JupyterLab

# %% [markdown]
# System health
#
# Environment auto-upgrade
# Automatically upgrades the instance if it's running. Learn more
# Next scheduled upgrade on August 5, 2024 7:00-7:59 AM GMT+08:00
# Upgrade schedule
# Select how often upgrades should be installed. If no upgrade is found, your instances won't be shut down.
#
# Weekly
#
# Monthly
# Weekday
# Monday
# Hour
# 7:00-7:59 AM
# Reporting
#
# Report system health
# Verifies status of core services. Learn more
#
# Report custom metrics to Cloud Monitoring
# Collect system status and JupyterLab metrics. Learn more
#
# Install Cloud Monitoring
# Report system and application metrics (disk, CPU, network and process). Learn more
#
# Report DNS status for required Google domains
# Verifies the DNS status of domains for proxy registration and status event reporting.
