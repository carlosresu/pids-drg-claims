# %%
https://medium.com/google-cloud/remote-to-vertex-ai-workbench-instances-over-an-iap-tunnel-with-vs-code-5c052f2cc7fa

# %%
https://www.googlecloudcommunity.com/gc/AI-ML/Vertex-AI-Workbench-Instance-provisions-seemingly-forever/m-p/710732

# %%
Host drg-data-pipeline
    HostName compute.204860004552174004
    User jupyter
    IdentityFile "C:\Users\resur\.ssh\gcp-jupyter"
    CheckHostIP no
    HashKnownHosts no
    HostKeyAlias compute.204860004552174004
    IdentitiesOnly yes
    StrictHostKeyChecking yes
    UserKnownHostsFile "C:\Users\resur\.ssh\google_compute_known_hosts"
    ProxyCommand "C:\\Users\\resur\\AppData\\Local\\Google\\Cloud SDK\\google-cloud-sdk\\bin\\..\\platform\\bundledpython\\python.exe" "-S" "C:\\Users\\resur\\AppData\\Local\\Google\\Cloud SDK\\google-cloud-sdk\\bin\\..\\lib\\gcloud.py" compute start-iap-tunnel "drg-data-pipeline" "%p" --listen-on-stdin --project=gphdrg --zone=us-central1-a --verbosity=warning
    ProxyUseFdpass no

# %%
SSH into server:
Add jupyter public key to /home/jupyter/.ssh/authorized_keys

# %%
Disable OS login

# %%
SSH into server:
sudo mkdir -p /home/jupyter/.vscode-server
sudo chown jupyter:jupyter /home/jupyter/.vscode-server

# %%
https://cloud.google.com/iap/docs/using-tcp-forwarding#increasing_the_tcp_upload_bandwidth
Open PowerShell:
start (gcloud info --format="value(basic.python_location)") "-m pip install numpy"
$env:CLOUDSDK_PYTHON_SITEPACKAGES="1"
