# %%
import os
import papermill as pm

# Define paths
base_path = os.path.expanduser('~/drg-pipeline/data-cleaning')
notebook_path = os.path.join(base_path, '01-drg-cleaning-v2.ipynb')
output_path = os.path.join(base_path, 'debug', '01-drg-cleaning-v2.ipynb')  # Single output notebook
log_path = os.path.join(base_path, 'debug', 'drg-cleaning-v2.log')  # Single log file
year_to_load_path = os.path.join(base_path, 'cache', 'year_to_load.txt')

# Define parameters
years = [2022]  # Add all years you need to process

def write_year_to_file(year):
    """Writes the current year to the year_to_load file."""
    with open(year_to_load_path, 'w') as f:
        f.write(str(year))

def run_notebook(to_parallel, year):
    """
    Executes the notebook with the given TO_PARALLEL setting for a specific year.
    Returns True if the execution succeeds, otherwise False.
    """
    # Set the environment variable for parallel execution
    os.environ['TO_PARALLEL'] = str(to_parallel)

    try:
        # Execute the notebook with Papermill and log the output
        with open(log_path, 'a') as log_file:  # Use 'a' to append logs for all years
            pm.execute_notebook(
                notebook_path, 
                output_path,
                stdout_file=log_file,  # Capture stdout
                stderr_file=log_file   # Capture stderr
            )
        print(f"Notebook executed successfully for year {year} with TO_PARALLEL={to_parallel}.")
        return True  # Execution successful
    except pm.PapermillExecutionError as e:
        print(f"Notebook execution failed for year {year} with TO_PARALLEL={to_parallel}. Error:\n{e}")
        return False  # Execution failed

# Loop over the years with retry logic
for year in years:
    write_year_to_file(year)  # Write the current year to the year_to_load file

    # Try running the notebook with TO_PARALLEL = TRUE first
    if not run_notebook(True, year):
        print(f"Retrying for year {year} with TO_PARALLEL = FALSE...")
        # Retry with TO_PARALLEL = FALSE if the first attempt fails
        if not run_notebook(False, year):
            raise RuntimeError(f"Notebook execution failed for year {year} with both TO_PARALLEL = TRUE and FALSE.")

# Display final log content at the end
print("\nFinal Execution Log:")
with open(log_path, 'r') as log_file:
    print(log_file.read())
