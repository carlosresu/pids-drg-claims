# %%
# grouper_v5.i10 (source i10.csv)
CODE:STRING,
MDC:STRING,
PDC:STRING,
CC:STRING,
MAINCC:STRING,
CCROW:STRING,
HIV_AX:STRING,
TRAUMA:STRING,
SEX:STRING,
ACCPDX:STRING,
AGEDUSE:STRING,
AGEMIN:STRING,
AGEMAX:STRING,
AGEDMIN:STRING

# %%
# grouper_v5.proc (source proc.csv)
CODE:STRING,
ORP:STRING,
ORPTYPE:STRING,
SEX:STRING,
SITE:STRING,
PROCGR:STRING,
PCPART:STRING,
EXTLEV:STRING,
DESC:STRING,
DRGUSE:STRING,
MAYUN:STRING

# %%
# phic.acr_rvs_map (source: rvs_icd9cm.csv)
rvs:STRING,
rvs_desc:STRING,
icd9cm:STRING,
icd9_desc:STRING,
remarks:STRING,
marc_remarks:STRING,
proc_category:STRING,
organ_system:STRING

# %%
# phic.acr_procedure (source acr_rvs.csv)
rvs:STRING,
rvu:STRING,
rvs_desc:STRING,
cr:STRING,
pf:STRING,
hci:STRING
